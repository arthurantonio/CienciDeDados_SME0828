# %% [markdown]
# <a href="https://colab.research.google.com/github/arthurantonio/CienciaDeDados_SME0828/blob/main/Questionario2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/') # Montar o drive
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# # **1° pergunta**

# %%
url = "https://gist.githubusercontent.com/aishwarya8615/89d9f36fc014dea62487f7347864d16a/raw/8629d284e13976dcb13bb0b27043224b9266fffa/Life_Expectancy_Data.csv"

df1 = pd.read_csv(url)
df1.head()
# Out:
#        Country Continent  Year      Status  Life_expectancy   Adult_Mortality  \
# 0  Afghanistan      Asia  2015  Developing              65.0              263
# 1  Afghanistan      Asia  2014  Developing              59.9              271
# 2  Afghanistan      Asia  2013  Developing              59.9              268
# 3  Afghanistan      Asia  2012  Developing              59.5              272
# 4  Afghanistan      Asia  2011  Developing              59.2              275
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  ...  Polio  \
# 0             62     0.01               71.279624         65.0  ...    6.0
# 1             64     0.01               73.523582         62.0  ...   58.0
# 2             66     0.01               73.219243         64.0  ...   62.0
# 3             69     0.01               78.184215         67.0  ...   67.0
# 4             71     0.01                7.097109         68.0  ...   68.0
#
# ...

# %%
paises = df1[['Country', 'Status']]
paises
# Out:
#           Country      Status
# 0     Afghanistan  Developing
# 1     Afghanistan  Developing
# 2     Afghanistan  Developing
# 3     Afghanistan  Developing
# 4     Afghanistan  Developing
# ...           ...         ...
# 2456     Zimbabwe  Developing
# 2457     Zimbabwe  Developing
# 2458     Zimbabwe  Developing
# 2459     Zimbabwe  Developing
# 2460     Zimbabwe  Developing
#
# [2461 rows x 2 columns]

# %%
paises = paises.drop_duplicates()
paises
# Out:
#                   Country      Status
# 0             Afghanistan  Developing
# 16                Albania  Developing
# 32                Algeria  Developing
# 48                 Angola  Developing
# 64    Antigua and Barbuda  Developing
# ...                   ...         ...
# 2381              Uruguay  Developing
# 2397           Uzbekistan  Developing
# 2413              Vanuatu  Developing
# 2429               Zambia  Developing
# 2445             Zimbabwe  Developing
#
# [156 rows x 2 columns]

# %%
#verificar se algum mudou de Developing para Developed, ou ao contrário
mudou = paises.duplicated(subset=['Country'])
for p in mudou:
  if(p != False):
    print(p)
#Não tem

# %%
mudou
# Out:
# 0       False
# 16      False
# 32      False
# 48      False
# 64      False
#         ...
# 2381    False
# 2397    False
# 2413    False
# 2429    False
# 2445    False
# Length: 156, dtype: bool

# %%
divisao = paises['Status'].value_counts()

# %%
divisao
# Out:
# Status
# Developing    128
# Developed      28
# Name: count, dtype: int64

# %%
# Plota o gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(divisao, labels=divisao.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(divisao))))
plt.title('Distribuição das Categorias')
plt.show()

# %% [markdown]
# # **2° pergunta**

# %%
url = "https://gist.githubusercontent.com/aishwarya8615/89d9f36fc014dea62487f7347864d16a/raw/8629d284e13976dcb13bb0b27043224b9266fffa/Life_Expectancy_Data.csv"

df2 = pd.read_csv(url)
df2.head()
# Out:
#        Country Continent  Year      Status  Life_expectancy   Adult_Mortality  \
# 0  Afghanistan      Asia  2015  Developing              65.0              263
# 1  Afghanistan      Asia  2014  Developing              59.9              271
# 2  Afghanistan      Asia  2013  Developing              59.9              268
# 3  Afghanistan      Asia  2012  Developing              59.5              272
# 4  Afghanistan      Asia  2011  Developing              59.2              275
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  ...  Polio  \
# 0             62     0.01               71.279624         65.0  ...    6.0
# 1             64     0.01               73.523582         62.0  ...   58.0
# 2             66     0.01               73.219243         64.0  ...   62.0
# 3             69     0.01               78.184215         67.0  ...   67.0
# 4             71     0.01                7.097109         68.0  ...   68.0
#
# ...

# %%
# Cria o histograma usando a coluna 'Idades'
plt.figure(figsize=(8, 6))
plt.hist(df2['Life_expectancy '], bins=12, edgecolor='black', color='skyblue')

# Configurações do gráfico
plt.title('Distribuição de Idades')
plt.xlabel('Idade')
plt.ylabel('Frequência')

# Mostra o gráfico
plt.show()

# %%
life_expectancy = df2['Life_expectancy ']
life_expectancy.describe()
# Out:
# count    2461.000000
# mean       69.464567
# std         9.639385
# min        36.300000
# 25%        63.400000
# 50%        72.300000
# 75%        76.000000
# max        89.000000
# Name: Life_expectancy , dtype: float64

# %% [markdown]
# # **3° pergunta**

# %%
url = "https://gist.githubusercontent.com/aishwarya8615/89d9f36fc014dea62487f7347864d16a/raw/8629d284e13976dcb13bb0b27043224b9266fffa/Life_Expectancy_Data.csv"

df3 = pd.read_csv(url)
df3.head()
# Out:
#        Country Continent  Year      Status  Life_expectancy   Adult_Mortality  \
# 0  Afghanistan      Asia  2015  Developing              65.0              263
# 1  Afghanistan      Asia  2014  Developing              59.9              271
# 2  Afghanistan      Asia  2013  Developing              59.9              268
# 3  Afghanistan      Asia  2012  Developing              59.5              272
# 4  Afghanistan      Asia  2011  Developing              59.2              275
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  ...  Polio  \
# 0             62     0.01               71.279624         65.0  ...    6.0
# 1             64     0.01               73.523582         62.0  ...   58.0
# 2             66     0.01               73.219243         64.0  ...   62.0
# 3             69     0.01               78.184215         67.0  ...   67.0
# 4             71     0.01                7.097109         68.0  ...   68.0
#
# ...

# %%
curr_pais = np.array([
    'Ireland',
    'Finland',
    'Netherlands',
    'Zambia',
    'Angola'
])

cores = ['#037d9c', '#3a06bf', '#291263', '#5d0991', '#820585']

# %%
for i, pais_i in enumerate(curr_pais):
  pais_df = df3.loc[df3['Country'] == pais_i]
  pais_df = pais_df.sort_values(by='Year')
  pais_df = pais_df[['Year', 'Life_expectancy ']]
  pais_df = pais_df.set_index('Year')

  ax = pais_df.plot(figsize=(10, 4), color=cores[i], linestyle='-', linewidth=2)
  ax.set_title(pais_i, fontsize=16, color=cores[i])
  ax.set_xlabel("Ano", fontsize=14)
  ax.set_ylabel("Expectativa de vida", fontsize=14)
  ax.grid(True, which='both', linestyle='--', linewidth=0.5)
  plt.tight_layout()
  plt.show()

# %% [markdown]
# # **4° pergunta**

# %%
url = "https://gist.githubusercontent.com/aishwarya8615/89d9f36fc014dea62487f7347864d16a/raw/8629d284e13976dcb13bb0b27043224b9266fffa/Life_Expectancy_Data.csv"

df4 = pd.read_csv(url)
df4.head()
# Out:
#        Country Continent  Year      Status  Life_expectancy   Adult_Mortality  \
# 0  Afghanistan      Asia  2015  Developing              65.0              263
# 1  Afghanistan      Asia  2014  Developing              59.9              271
# 2  Afghanistan      Asia  2013  Developing              59.9              268
# 3  Afghanistan      Asia  2012  Developing              59.5              272
# 4  Afghanistan      Asia  2011  Developing              59.2              275
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  ...  Polio  \
# 0             62     0.01               71.279624         65.0  ...    6.0
# 1             64     0.01               73.523582         62.0  ...   58.0
# 2             66     0.01               73.219243         64.0  ...   62.0
# 3             69     0.01               78.184215         67.0  ...   67.0
# 4             71     0.01                7.097109         68.0  ...   68.0
#
# ...

# %%
maior_mediana = 0
pais_maior = ''

for i, pais_i in enumerate(curr_pais):
  pais_df = df3.loc[df3['Country'] == pais_i]
  pais_df = pais_df['Schooling']

  if pais_df.median() > maior_mediana:
    maior_mediana = pais_df.median()
    pais_maior = pais_i

  ax = pais_df.plot.box(figsize=(8, 6), color = cores[i])
  ax.set_title(f'Schooling: {pais_i}', fontsize=16, color = cores[i])
  ax.set_ylabel('Valores', fontsize=12)
  plt.show()

# %%
print(f"A maior mediana é de {maior_mediana} e o país é: {pais_maior}")
# Out:
# A maior mediana é de 17.75 e o país é: Ireland

# %% [markdown]
# # **5° pergunta**

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.worldometers.info/world-population/population-by-country/"
# Send a GET request to the URL
response = requests.get(url)
# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')
# Find the table containing the population data
table = soup.find('table', {'id': 'example2'})
# Convert the table to a Pandas DataFrame
df = pd.read_html(str(table))[0]
# Print the DataFrame
df.head()
# Out:
# <ipython-input-55-ef9f2d57c7b0>:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
#    # Country (or dependency)  Population  (2024) Yearly  Change  Net  Change  \
# 0  1                   India          1450935791         0.89 %     12866195
# 1  2                   China          1419321278        -0.23 %     -3263655
# 2  3           United States           345426571         0.57 %      1949236
# 3  4               Indonesia           283487931         0.82 %      2297864
# 4  5                Pakistan           251269164         1.52 %      3764669
#
#    Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  Fert.  Rate  \
# 0               488           2973190          -630830          2.0
# 1               151           9388211          -318992          1.0
# ...

# %%
df = df.drop(df.columns[[0, 1]], axis=1)
df
# Out:
#      Population  (2024) Yearly  Change  Net  Change  Density  (P/Km²)  \
# 0            1450935791         0.89 %     12866195               488
# 1            1419321278        -0.23 %     -3263655               151
# 2             345426571         0.57 %      1949236                38
# 3             283487931         0.82 %      2297864               156
# 4             251269164         1.52 %      3764669               326
# ..                  ...            ...          ...               ...
# 229                4389        -0.70 %          -31                44
# 230                3470        -0.20 %           -7                 0
# 231                2506         4.55 %          109               251
# 232                1819         0.11 %            2                 7
# 233                 496         0.00 %            0              1240
#
#      Land Area  (Km²)  Migrants  (net)  Fert.  Rate  Med.  Age Urban  Pop %  \
# ...

# %%
df.isnull().sum()
# Out:
# Population  (2024)    0
# Yearly  Change        0
# Net  Change           0
# Density  (P/Km²)      0
# Land Area  (Km²)      0
# Migrants  (net)       0
# Fert.  Rate           0
# Med.  Age             0
# Urban  Pop %          0
# World  Share          0
# dtype: int64

# %%
df.dtypes
# Out:
# Population  (2024)      int64
# Yearly  Change         object
# Net  Change             int64
# Density  (P/Km²)        int64
# Land Area  (Km²)        int64
# Migrants  (net)         int64
# Fert.  Rate           float64
# Med.  Age               int64
# Urban  Pop %           object
# World  Share           object
# dtype: object

# %%
def porcentagem_para_float(valor):
  if(valor[-1] == '%'):
    return float(valor.replace(' %', '')) / 100
  else:
    return np.nan

# %%
colunasStrings =df.select_dtypes(include='object')

for coluna in colunasStrings:
    df[coluna] = df[coluna].apply(porcentagem_para_float)

# %%
df = df.dropna()

# %%
df
# Out:
#      Population  (2024)  Yearly  Change  Net  Change  Density  (P/Km²)  \
# 0            1450935791          0.0089     12866195               488
# 1            1419321278         -0.0023     -3263655               151
# 2             345426571          0.0057      1949236                38
# 3             283487931          0.0082      2297864               156
# 4             251269164          0.0152      3764669               326
# ..                  ...             ...          ...               ...
# 228                5237         -0.0098          -52                13
# 229                4389         -0.0070          -31                44
# 230                3470         -0.0020           -7                 0
# 231                2506          0.0455          109               251
# 232                1819          0.0011            2                 7
#
#      Land Area  (Km²)  Migrants  (net)  Fert.  Rate  Med.  Age  Urban  Pop %  \
# ...

# %%
matriz_correlacao = df.corr()
matriz_correlacao
# Out:
#                     Population  (2024)  Yearly  Change  Net  Change  \
# Population  (2024)            1.000000       -0.033162     0.520614
# Yearly  Change               -0.033162        1.000000     0.226035
# Net  Change                   0.520614        0.226035     1.000000
# Density  (P/Km²)             -0.012379       -0.015018    -0.014427
# Land Area  (Km²)              0.446589       -0.015043     0.091422
# Migrants  (net)              -0.238258        0.065193    -0.226300
# Fert.  Rate                  -0.044902        0.665769     0.254260
# Med.  Age                     0.002497       -0.698613    -0.272565
# Urban  Pop %                 -0.028942       -0.219276    -0.173140
# World  Share                  0.999999       -0.033107     0.520680
#
#                     Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  \
# Population  (2024)         -0.012379          0.446589        -0.238258
# Yearly  Change             -0.015018         -0.015043         0.065193
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(matriz_correlacao, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Mapa de Calor das Correlações')
plt.show()

# %%
# Transformar a matriz em um DataFrame e resetar o índice
correlacoes = matriz_correlacao.unstack().reset_index()
correlacoes.columns = ['Variável 1', 'Variável 2', 'Correlação']

# Remover as correlações de uma variável consigo mesma
correlacoes = correlacoes[correlacoes['Variável 1'] != correlacoes['Variável 2']]

# Remover duplicatas (já que a matriz de correlação é simétrica)
correlacoes = correlacoes.drop_duplicates(subset=['Correlação'])

# Selecionar as 5 maiores correlações (em valor absoluto, se necessário)
maiores_correlações = correlacoes.nlargest(5, 'Correlação')

maiores_correlações
# Out:
#             Variável 1        Variável 2  Correlação
# 9   Population  (2024)      World  Share    0.999999
# 16      Yearly  Change       Fert.  Rate    0.665769
# 29         Net  Change      World  Share    0.520680
# 2   Population  (2024)       Net  Change    0.520614
# 4   Population  (2024)  Land Area  (Km²)    0.446589

# %%
for index, row in maiores_correlações.iterrows():
    #print(f"A correlação entre {row['Variável 1']} e {row['Variável 2']} é {row['Correlação']:.2f}")

    plt.figure(figsize=(8, 6))
    sns.regplot(x=df[row['Variável 1']], y=df[row['Variável 2']], data=df, scatter_kws={'color': 'blue'})

    # Adicionando título e rótulos
    plt.title('Gráfico de Dispersão com Linha de Tendência')
    plt.xlabel('Coluna A')
    plt.ylabel('Coluna B')

    # Exibindo o gráfico
    plt.show()
